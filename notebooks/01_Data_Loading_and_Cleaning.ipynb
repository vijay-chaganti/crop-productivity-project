# %% [markdown]
# # 01 - Data Loading and Cleaning
# Crop Productivity Prediction Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the dataset
data_agri = pd.read_csv('../data/Agriculture-Data.csv')
data_agri.head(10)
# Out:
#                Crop  Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  \
# 0  Total Foodgrains     158.8     168.6     171.3     159.4     178.9
# 1              Rice     200.8     207.9     213.3     191.6     206.4
# 2             Wheat     131.6     136.4     140.1     140.3     150.8
# 3             Jowar     124.3     137.8     126.0     116.5     121.8
# 4             Bajra     136.4     161.5     143.9       NaN     167.9
# 5             Maize     198.8     249.6     259.8     220.1     286.0
# 6              Ragi      56.1      83.6      79.3      73.4      85.2
# 7     Small millets      53.9      61.9      50.0      42.9      82.0
# 8            Barley      88.1      79.3     112.0      89.9     110.3
# 9    Coarse Cereals     138.5     166.4     163.5       NaN     178.4
#
#    Area2011  Area2012  Area2013  Area2014  Area2015  Yield2011  Yield2012  \
# 0     128.5     128.8     127.6     126.0     131.7      123.6      130.9
# ...

# %%
# Shape of dataset
print("Rows and Columns:", data_agri.shape)

# Data types and info
data_agri.info()
# Out:
# Rows and Columns: (55, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Crop       55 non-null     object
#  1   Prod2011   55 non-null     float64
#  2   Prod2012   55 non-null     float64
#  3   Prod2013   55 non-null     float64
#  4   Prod2014   49 non-null     float64
#  5   Prod2015   55 non-null     float64
#  6   Area2011   55 non-null     float64
#  7   Area2012   55 non-null     float64
#  8   Area2013   55 non-null     float64
#  9   Area2014   55 non-null     float64
#  10  Area2015   55 non-null     float64
#  11  Yield2011  55 non-null     float64
#  12  Yield2012  55 non-null     float64
#  13  Yield2013  55 non-null     float64
#  14  Yield2014  55 non-null     float64
#  15  Yield2015  55 non-null     float64
#  16  Weather    55 non-null     object
#  17  Season     55 non-null     object
# ...

# %%
# Checking null values
print("Null Values:\n", data_agri.isnull().sum())
# Out:
# Null Values:
#  Crop         0
# Prod2011     0
# Prod2012     0
# Prod2013     0
# Prod2014     6
# Prod2015     0
# Area2011     0
# Area2012     0
# Area2013     0
# Area2014     0
# Area2015     0
# Yield2011    0
# Yield2012    0
# Yield2013    0
# Yield2014    0
# Yield2015    0
# Weather      0
# Season       0
# dtype: int64

# %%
# Dropping unstable rows
data_agri.drop([38], inplace=True)

# Filling null values with median
def impute_median(series):
    return series.fillna(series.median())

data_agri.Prod2014 = data_agri['Prod2014'].transform(impute_median)

# Verify no nulls remain
print("Null values after cleaning:\n", data_agri.isnull().sum())
# Out:
# Null values after cleaning:
#  Crop         0
# Prod2011     0
# Prod2012     0
# Prod2013     0
# Prod2014     0
# Prod2015     0
# Area2011     0
# Area2012     0
# Area2013     0
# Area2014     0
# Area2015     0
# Yield2011    0
# Yield2012    0
# Yield2013    0
# Yield2014    0
# Yield2015    0
# Weather      0
# Season       0
# dtype: int64

# %%
# Save cleaned data to reuse in other notebooks
data_agri.to_csv('../data/cleaned_agriculture_data.csv', index=False)
print("Cleaned data saved successfully!")
# Out:
# Cleaned data saved successfully!
